# %% [markdown]
# # Continous Wavelet Transform

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from scipy.signal import cwt,ricker,morlet

# %%
sub_data = pd.read_csv("../../windowed_data/sub_1.csv")

# %%
df_X = sub_data.drop(columns=["arousal","valence"])
df_y = sub_data[["arousal","valence"]]

# %%
window = df_X.iloc[np.random.randint(0,len(df_X)-1)]

coeffs = cwt(window,ricker,widths=np.arange(1,101))
# Out:
# C:\Users\Dhyanesh Panchal\AppData\Local\Temp\ipykernel_33820\4075702832.py:3: DeprecationWarning: scipy.signal.cwt is deprecated in SciPy 1.12 and will be removed
# in SciPy 1.15. We recommend using PyWavelets instead.
#
#   coeffs = cwt(window,ricker,widths=np.arange(1,101))

# %%
plt.imshow(coeffs,cmap='coolwarm')

# %%
plt.plot(window)
